# %%
import warnings
disable_warnings = warnings.filterwarnings('ignore')
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# from statsforecast import StatsForecast
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller, pacf, acf
from sklearn.metrics import mean_squared_error
from datetime import timedelta

# %%
orders_train = pd.read_csv('orders_train.txt', sep=';', encoding='utf8')
orders_class = pd.read_csv('orders_class.txt', sep=';', encoding='utf8')

# %%
df_whole = pd.concat([orders_train, orders_class], ignore_index=True)
df_whole
# Out:
#           orderID   orderDate articleID  colorCode sizeCode  productGroup  \
# 0        a1000001  2014-01-01  i1000382       1972       44           3.0
# 1        a1000001  2014-01-01  i1000550       3854       44           3.0
# 2        a1000002  2014-01-01  i1001991       2974       38           8.0
# 3        a1000002  2014-01-01  i1001999       1992       38           8.0
# 4        a1000003  2014-01-01  i1001942       1968       42           8.0
# ...           ...         ...       ...        ...      ...           ...
# 2666258  a1855500  2015-12-31  i1004262      20363       38        1231.0
# 2666259  a1855501  2015-12-31  i1000397       1000       44           3.0
# 2666260  a1855501  2015-12-31  i1001099       3085       42           3.0
# 2666261  a1855501  2015-12-31  i1004207      10107       42        1231.0
# 2666262  a1855502  2015-12-31  i1002423       1116       38          14.0
#
#          quantity  price    rrp voucherID  voucherAmount customerID  deviceID  \
# 0               1  10.00  29.99         0            0.0   c1010575         2
# 1               1  20.00  39.99         0            0.0   c1010575         2
# 2               1  35.00  49.99         0            0.0   c1045905         4
# 3               1  49.99  49.99         0            0.0   c1045905         4
# 4               1  10.00  35.99         0            0.0   c1089295         2
# ...           ...    ...    ...       ...            ...        ...       ...
# 2666258         1  29.99  29.99         0            0.0   c1225101         5
# 2666259         1  17.99  17.99         0            0.0   c1065053         5
# 2666260         1   9.00  29.99         0            0.0   c1065053         5
# 2666261         1  17.99  17.99         0            0.0   c1065053         5
# 2666262         1  45.00  89.99         0            0.0   c1082444         5
#
#         paymentMethod  returnQuantity
# 0                BPRG             0.0
# 1                BPRG             0.0
# 2                BPRG             0.0
# 3                BPRG             1.0
# 4            PAYPALVC             0.0
# ...               ...             ...
# 2666258          BPRG             NaN
# 2666259      PAYPALVC             NaN
# 2666260      PAYPALVC             NaN
# 2666261      PAYPALVC             NaN
# 2666262          BPRG             NaN
#
# [2666263 rows x 15 columns]

# %%
df_orders = df_whole[["orderDate","quantity"]].groupby("orderDate").sum()
df_orders
# Out:
#             quantity
# orderDate
# 2014-01-01      1245
# 2014-01-02      1586
# 2014-01-03      1709
# 2014-01-04      2495
# 2014-01-05      3485
# ...              ...
# 2015-12-27      2783
# 2015-12-28      4968
# 2015-12-29      4061
# 2015-12-30      3224
# 2015-12-31      1992
#
# [730 rows x 1 columns]

# %%
# df_orders_train = df_orders.loc[:'2015-11-30']
# df_orders_test = df_orders.loc['2015-12-01':'2015-12-14']

# %%
# fig = px.line(df_orders_train, x=df_orders_train.index, y="quantity", title='Daily sales', template="simple_white")
# fig.add_trace(go.Scatter(x=df_orders_test.index, y=df_orders_test["quantity"], mode='lines', name='Test Quantity'))
# fig.update_layout(title_x=0.5, margin={'l': 30, 'b': 40, 't': 30, 'r': 40}, hovermode='x unified', hoverlabel=dict(bgcolor="white"))
# fig.update_xaxes(title_text="Date")
# fig.update_yaxes(title_text="Quantity")
# fig.show()

# %%
# Generate the ACF plot using statsmodels
acf_fig, ax = plt.subplots(figsize=(12, 8))  # Adjust the size as needed (width, height)
plot_acf(df_orders, lags=30, ax=ax)
plt.show()

# %%
# Perform the ADF test on the time series
result = adfuller(df_orders['quantity'])

# Extract the test statistic and p-value from the result
test_statistic = result[0]
p_value = result[1]

# Print the test statistic and p-value
print(f'Test statistic: {test_statistic:.4f}')
print(f'p-value: {p_value:.4f}')
# Out:
# Test statistic: -2.5243
# p-value: 0.1097

# %%
# Compute the first and second differences of the time series
diff1 = df_orders['quantity'].diff().dropna()
diff2 = diff1.diff().dropna()

# Perform the ADF test on the differences and print the results
for i, diff in enumerate([diff1, diff2], start=1):
    result = adfuller(diff)
    print(f'{i} difference: Test statistic = {result[0]:.4f}, p-value = {result[1]:.4f}')
# Out:
# 1 difference: Test statistic = -8.5825, p-value = 0.0000
# 2 difference: Test statistic = -12.2026, p-value = 0.0000

# %%
pacf_fig, ax = plt.subplots(figsize=(12, 8))  # Adjust the size as needed (width, height)
plot_pacf(diff1, lags=30, ax=ax)
plt.show()

# %%
acf_fig, ax = plt.subplots(figsize=(12, 8))  # Adjust the size as needed (width, height)
plot_acf(diff1, lags=30, ax=ax)
plt.show()

# %%
# Define the start and end dates of the sliding window
start_date = pd.to_datetime('2014-01-01')
end_date = pd.to_datetime('2015-12-31')

# Define the window size as 1 year
window_size = pd.DateOffset(years=1)

# Initialize an empty list to hold the sliding window years
sliding_window= []

# Loop over the time periods and extract the corresponding dates
while start_date + window_size <= end_date:
    sliding_window.append((start_date.strftime('%Y-%m-%d'), (start_date + window_size).strftime('%Y-%m-%d')))
    start_date += pd.DateOffset(months=1)

sliding_window
# Out:
# [('2014-01-01', '2015-01-01'),
#  ('2014-02-01', '2015-02-01'),
#  ('2014-03-01', '2015-03-01'),
#  ('2014-04-01', '2015-04-01'),
#  ('2014-05-01', '2015-05-01'),
#  ('2014-06-01', '2015-06-01'),
#  ('2014-07-01', '2015-07-01'),
#  ('2014-08-01', '2015-08-01'),
#  ('2014-09-01', '2015-09-01'),
#  ('2014-10-01', '2015-10-01'),
#  ('2014-11-01', '2015-11-01'),
#  ('2014-12-01', '2015-12-01')]

# %%
# Define the start and end dates of the sliding window
start_date = pd.to_datetime('2014-01-01')
end_date = pd.to_datetime('2015-12-31')

# Define the training size as 1 year
train_size = pd.DateOffset(years=1)
test_size = pd.DateOffset(months=1)

# Initialize an empty list to hold the sliding window dates
sliding_window = []

# Loop over the time periods and extract the corresponding dates
while start_date + train_size <= end_date:
    window_start = start_date.strftime('%Y-%m-%d')
    window_end_train = (start_date + train_size - pd.DateOffset(days=1)).strftime('%Y-%m-%d')
    window_end_test = (start_date + train_size + test_size - pd.DateOffset(days=1)).strftime('%Y-%m-%d')
    number_of_steps = (pd.to_datetime(window_end_test) - pd.to_datetime(window_end_train)).days
    sliding_window.append((window_start, window_end_train, window_end_test,number_of_steps))
    start_date += pd.DateOffset(months=1)

sliding_window
# Out:
# [('2014-01-01', '2014-12-31', '2015-01-31', 31),
#  ('2014-02-01', '2015-01-31', '2015-02-28', 28),
#  ('2014-03-01', '2015-02-28', '2015-03-31', 31),
#  ('2014-04-01', '2015-03-31', '2015-04-30', 30),
#  ('2014-05-01', '2015-04-30', '2015-05-31', 31),
#  ('2014-06-01', '2015-05-31', '2015-06-30', 30),
#  ('2014-07-01', '2015-06-30', '2015-07-31', 31),
#  ('2014-08-01', '2015-07-31', '2015-08-31', 31),
#  ('2014-09-01', '2015-08-31', '2015-09-30', 30),
#  ('2014-10-01', '2015-09-30', '2015-10-31', 31),
#  ('2014-11-01', '2015-10-31', '2015-11-30', 30),
#  ('2014-12-01', '2015-11-30', '2015-12-31', 31)]

# %%
# Initialize an empty list to hold the validation errors
validation_errors = []
for i, (start_date, end_date, val_date, steps) in enumerate(sliding_window):
    # Define the ARIMA model with p=6, d=1, and q=7
    # model = ARIMA(df_orders[start_date:end_date], order=(6, 1, 7), freq='D')

    # # Fit the model to the data
    # model_fit = model.fit()

    # Print the summary of the model
    # print(model_fit.summary())

    # Make predictions for the next 31 time steps
    # forecast = model_fit.forecast(steps=(val_date - end_date).days)

    # Print the forecasted values
    # print(forecast)
    print(steps)
    
    print(f'Iteration {i + 1}: Training dates = {start_date} - {end_date}, Validation dates = {val_date}')
# Out:
# 31
# Iteration 1: Training dates = 2014-01-01 - 2014-12-31, Validation dates = 2015-01-31
# 28
# Iteration 2: Training dates = 2014-02-01 - 2015-01-31, Validation dates = 2015-02-28
# 31
# Iteration 3: Training dates = 2014-03-01 - 2015-02-28, Validation dates = 2015-03-31
# 30
# Iteration 4: Training dates = 2014-04-01 - 2015-03-31, Validation dates = 2015-04-30
# 31
# Iteration 5: Training dates = 2014-05-01 - 2015-04-30, Validation dates = 2015-05-31
# 30
# Iteration 6: Training dates = 2014-06-01 - 2015-05-31, Validation dates = 2015-06-30
# 31
# Iteration 7: Training dates = 2014-07-01 - 2015-06-30, Validation dates = 2015-07-31
# 31
# Iteration 8: Training dates = 2014-08-01 - 2015-07-31, Validation dates = 2015-08-31
# 30
# Iteration 9: Training dates = 2014-09-01 - 2015-08-31, Validation dates = 2015-09-30
# 31
# Iteration 10: Training dates = 2014-10-01 - 2015-09-30, Validation dates = 2015-10-31
# 30
# Iteration 11: Training dates = 2014-11-01 - 2015-10-31, Validation dates = 2015-11-30
# 31
# Iteration 12: Training dates = 2014-12-01 - 2015-11-30, Validation dates = 2015-12-31

# %%
# Define the ARIMA model with p=6, d=1, and q=7
model = ARIMA(df_orders_train['quantity'], order=(7, 1, 7), freq='D')

# Fit the model to the data
model_fit = model.fit()

# Print the summary of the model
print(model_fit.summary())

# Make predictions for the next 31 time steps
forecast = model_fit.forecast(steps=14)

# Print the forecasted values
print(forecast)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               quantity   No. Observations:                  699
# Model:                 ARIMA(7, 1, 7)   Log Likelihood               -5471.363
# Date:                Wed, 26 Jul 2023   AIC                          10972.727
# Time:                        10:55:58   BIC                          11040.950
# Sample:                    01-01-2014   HQIC                         10999.102
#                          - 11-30-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2477      0.035     -7.146      0.000      -0.316      -0.180
# ar.L2         -0.2601      0.034     -7.763      0.000      -0.326      -0.194
# ar.L3         -0.2677      0.033     -8.019      0.000      -0.333      -0.202
# ar.L4         -0.2594      0.033     -7.777      0.000      -0.325      -0.194
# ar.L5         -0.2549      0.033     -7.652      0.000      -0.320      -0.190
# ar.L6         -0.2650      0.034     -7.791      0.000      -0.332      -0.198
# ar.L7          0.7244      0.032     22.494      0.000       0.661       0.787
# ma.L1         -0.0658      0.034     -1.947      0.052      -0.132       0.000
# ma.L2         -0.0147      0.033     -0.441      0.659      -0.080       0.051
# ma.L3          0.0065      0.031      0.209      0.834      -0.055       0.068
# ma.L4          0.0117      0.037      0.318      0.751      -0.060       0.084
# ma.L5         -0.0274      0.035     -0.778      0.437      -0.096       0.042
# ma.L6         -0.0142      0.038     -0.375      0.707      -0.088       0.060
# ma.L7         -0.8320      0.033    -25.090      0.000      -0.897      -0.767
# sigma2      3.848e+05    1.1e+04     35.141      0.000    3.63e+05    4.06e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.76   Jarque-Bera (JB):              5469.62
# Prob(Q):                              0.05   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                             1.51
# Prob(H) (two-sided):                  0.50   Kurtosis:                        16.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 2015-12-01    3696.147429
# 2015-12-02    4283.483560
# 2015-12-03    4333.526784
# 2015-12-04    3660.216312
# 2015-12-05    3236.515716
# 2015-12-06    3746.809159
# 2015-12-07    3126.409593
# 2015-12-08    4000.227030
# 2015-12-09    4502.237276
# 2015-12-10    4507.004078
# 2015-12-11    3796.717985
# 2015-12-12    3326.458307
# 2015-12-13    3807.464083
# 2015-12-14    3190.592008
# Freq: D, Name: predicted_mean, dtype: float64

# %%
fig = px.line(df_orders["2015-10-01":], x=df_orders["2015-10-01":].index, y="quantity", title='Daily sales', template="simple_white")
# fig.update_traces(line=dict(width=1.5))
fig.add_trace(go.Scatter(x=forecast.index, y=forecast.values, mode='lines', name='Forecast Quantity'))
fig.update_layout(title_x=0.5, margin={'l': 30, 'b': 40, 't': 30, 'r': 40}, hovermode='x unified', hoverlabel=dict(bgcolor="white"))
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="Quantity")
fig.show()

# %%
rmse = mean_squared_error(df_orders_test['quantity'], forecast, squared=False)
rmse
# Out:
# 886.6168080293307

# %%
# df_orders_train["holiday"] = 0
# df_orders_train.loc[["2014-12-24", "2014-12-31"], "holiday"] = 1
# df_orders_test["holiday"] = 0
# df_orders_test.loc[["2015-12-24", "2015-12-31"], "holiday"] = 1

# %%
# # Convert the index to a datetime index
# df_orders_train.index = pd.to_datetime(df_orders_train.index)
# df_orders_test.index = pd.to_datetime(df_orders_test.index)

# # Create dummy variables for 'day_of_week' in both DataFrames
# df_dummies_train = pd.get_dummies(df_orders_train.index.dayofweek, prefix='day_of_week')
# df_dummies_train.index = df_orders_train.index
# df_dummies_test = pd.get_dummies(df_orders_test.index.dayofweek, prefix='day_of_week')
# df_dummies_test.index = df_orders_test.index


# # Rename the columns of the dummy variable DataFrame to correspond to the name of the days
# df_dummies_train.columns = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# df_dummies_test.columns = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# # Concatenate the original DataFrame and the dummy variable DataFrame
# df_orders_train = pd.concat([df_orders_train, df_dummies_train], axis=1)
# df_orders_test = pd.concat([df_orders_test, df_dummies_test], axis=1)

# %%
# Define the SARIMA model with p=6, d=1, q=7, P=1, D=1, and Q=1
model = SARIMAX(endog = df_orders_train['quantity'], exog=df_orders_train.iloc[:, 1:] ,order=(3, 1, 3), seasonal_order=(4, 1, 4, 7), freq='D')

# Fit the model to the data
model_fit = model.fit()

# Print the summary of the model
print(model_fit.summary())

# Make predictions for the next 31 time steps
exog_forecast = df_orders_test.iloc[:, 1:]
forecast = model_fit.forecast(steps=31, exog=exog_forecast)

# Print the forecasted values
print(forecast)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Programming\Demand Forecast\Forecast.ipynb Cell 17 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Programming/Demand%20Forecast/Forecast.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # Define the SARIMA model with p=6, d=1, q=7, P=1, D=1, and Q=1
# ----> <a href='vscode-notebook-cell:/c%3A/Programming/Demand%20Forecast/Forecast.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> model = SARIMAX(endog = df_orders_train['quantity'], exog=df_orders_train.iloc[:, 1:] ,order=(3, 1, 3), seasonal_order=(4, 1, 4, 7), freq='D')
#       <a href='vscode-notebook-cell:/c%3A/Programming/Demand%20Forecast/Forecast.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> # Fit the model to the data
#       <a href='vscode-notebook-cell:/c%3A/Programming/Demand%20Forecast/Forecast.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> model_fit = model.fit()
#
# File d:\miniconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:328, in SARIMAX.__init__(self, endog, exog, order, seasonal_order, trend, measurement_error, time_varying_regression, mle_regression, simple_differencing, enforce_stationarity, enforce_invertibility, hamilton_representation, concentrate_scale, trend_offset, use_exact_diffuse, dates, freq, missing, validate_specification, **kwargs)
#     318 def __init__(self, endog, exog=None, order=(1, 0, 0),
#     319              seasonal_order=(0, 0, 0, 0), trend=None,
#     320              measurement_error=False, time_varying_regression=False,
#    (...)
#     325              freq=None, missing='none', validate_specification=True,
#     326              **kwargs):
# --> 328     self._spec = SARIMAXSpecification(
#     329         endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     330         trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#     331         concentrate_scale=concentrate_scale, dates=dates, freq=freq,
#     332         missing=missing, validate_specification=validate_specification)
#     333     self._params = SARIMAXParams(self._spec)
#     335     # Save given orders
#
# File d:\miniconda\lib\site-packages\statsmodels\tsa\arima\specification.py:446, in SARIMAXSpecification.__init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     441         exog = np.c_[trend_data, exog]
#     443 # Create an underlying time series model, to handle endog / exog,
#     444 # especially validating shapes, retrieving names, and potentially
#     445 # providing us with a time series index
# --> 446 self._model = TimeSeriesModel(endog, exog=exog, dates=dates, freq=freq,
#     447                               missing=missing)
#     448 self.endog = None if faux_endog else self._model.endog
#     449 self.exog = self._model.exog
#
# File d:\miniconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:468, in TimeSeriesModel.__init__(self, endog, exog, dates, freq, missing, **kwargs)
#     465 def __init__(
#     466     self, endog, exog=None, dates=None, freq=None, missing="none", **kwargs
#     467 ):
# --> 468     super().__init__(endog, exog, missing=missing, **kwargs)
#     470     # Date handling in indexes
#     471     self._init_dates(dates, freq)
#
# File d:\miniconda\lib\site-packages\statsmodels\base\model.py:267, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     266 def __init__(self, endog, exog=None, **kwargs):
# --> 267     super().__init__(endog, exog, **kwargs)
#     268     self.initialize()
#
# File d:\miniconda\lib\site-packages\statsmodels\base\model.py:92, in Model.__init__(self, endog, exog, **kwargs)
#      90 missing = kwargs.pop('missing', 'none')
#      91 hasconst = kwargs.pop('hasconst', None)
# ---> 92 self.data = self._handle_data(endog, exog, missing, hasconst,
#      93                               **kwargs)
#      94 self.k_constant = self.data.k_constant
#      95 self.exog = self.data.exog
#
# File d:\miniconda\lib\site-packages\statsmodels\base\model.py:132, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     131 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 132     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     133     # kwargs arrays could have changed, easier to just attach here
#     134     for key in kwargs:
#
# File d:\miniconda\lib\site-packages\statsmodels\base\data.py:673, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670     exog = np.asarray(exog)
#     672 klass = handle_data_class_factory(endog, exog)
# --> 673 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     674              **kwargs)
#
# File d:\miniconda\lib\site-packages\statsmodels\base\data.py:86, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      84 self.const_idx = None
#      85 self.k_constant = 0
# ---> 86 self._handle_constant(hasconst)
#      87 self._check_integrity()
#      88 self._cache = {}
#
# File d:\miniconda\lib\site-packages\statsmodels\base\data.py:176, in ModelData._handle_constant(self, hasconst)
#     173 augmented_exog = np.column_stack(
#     174             (np.ones(self.exog.shape[0]), self.exog))
#     175 rank_augm = np.linalg.matrix_rank(augmented_exog)
# --> 176 rank_orig = np.linalg.matrix_rank(self.exog)
#     177 self.k_constant = int(rank_orig == rank_augm)
#     178 self.const_idx = None
#
# File <__array_function__ internals>:180, in matrix_rank(*args, **kwargs)
#
# File d:\miniconda\lib\site-packages\numpy\linalg\linalg.py:1891, in matrix_rank(A, tol, hermitian)
#    1889 S = svd(A, compute_uv=False, hermitian=hermitian)
#    1890 if tol is None:
# -> 1891     tol = S.max(axis=-1, keepdims=True) * max(A.shape[-2:]) * finfo(S.dtype).eps
#    1892 else:
#    1893     tol = asarray(tol)[..., newaxis]
#
# File d:\miniconda\lib\site-packages\numpy\core\_methods.py:40, in _amax(a, axis, out, keepdims, initial, where)
#      38 def _amax(a, axis=None, out=None, keepdims=False,
#      39           initial=_NoValue, where=True):
# ---> 40     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
# Define the SARIMA model with p=6, d=1, q=7, P=1, D=1, and Q=1
model = SARIMAX(df_orders_train['quantity'],order=(3, 1, 3), seasonal_order=(4, 1, 4, 7), freq='D')

# Fit the model to the data
model_fit = model.fit()

# Print the summary of the model
print(model_fit.summary())

# Make predictions for the next 31 time steps
# exog_forecast = df_orders_test.iloc[:, 1:]
forecast = model_fit.forecast(steps=14)

# Print the forecasted values
print(forecast)
# Out:
#                                           SARIMAX Results
# ====================================================================================================
# Dep. Variable:                                     quantity   No. Observations:                  699
# Model:             SARIMAX(3, 1, 3)x(4, 1, [1, 2, 3, 4], 7)   Log Likelihood               -5443.349
# Date:                                      Wed, 26 Jul 2023   AIC                          10916.699
# Time:                                              11:02:29   BIC                          10984.771
# Sample:                                          01-01-2014   HQIC                         10943.028
#                                                - 11-30-2015
# Covariance Type:                                        opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3799      0.084     -4.520      0.000      -0.545      -0.215
# ar.L2         -0.4283      0.093     -4.630      0.000      -0.610      -0.247
# ar.L3          0.5576      0.076      7.316      0.000       0.408       0.707
# ma.L1          0.0020      0.070      0.028      0.978      -0.136       0.140
# ma.L2          0.0924      0.074      1.250      0.211      -0.053       0.237
# ma.L3         -0.9143      0.068    -13.523      0.000      -1.047      -0.782
# ar.S.L7       -0.8339      0.362     -2.301      0.021      -1.544      -0.124
# ar.S.L14       0.8078      0.359      2.247      0.025       0.103       1.512
# ar.S.L21       0.7734      0.307      2.520      0.012       0.172       1.375
# ar.S.L28       0.0467      0.094      0.497      0.619      -0.137       0.231
# ma.S.L7       -0.0500      0.373     -0.134      0.893      -0.781       0.681
# ma.S.L14      -1.6087      0.372     -4.325      0.000      -2.338      -0.880
# ma.S.L21      -0.0190      0.322     -0.059      0.953      -0.650       0.612
# ma.S.L28       0.6863      0.317      2.163      0.031       0.064       1.308
# sigma2      6.178e+05   3.88e+04     15.936      0.000    5.42e+05    6.94e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):              6487.93
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                             1.65
# Prob(H) (two-sided):                  0.54   Kurtosis:                        17.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 2015-12-01    3699.021231
# 2015-12-02    4146.871791
# 2015-12-03    3972.377313
# 2015-12-04    3269.544379
# 2015-12-05    2843.751311
# 2015-12-06    3388.343823
# 2015-12-07    2670.307380
# 2015-12-08    3609.827305
# 2015-12-09    4009.606499
# 2015-12-10    3890.335485
# 2015-12-11    3208.422205
# 2015-12-12    2903.212009
# 2015-12-13    3251.336207
# 2015-12-14    2673.087223
# Freq: D, Name: predicted_mean, dtype: float64

# %%
fig = px.line(df_orders["2015-10-01":], x=df_orders["2015-10-01":].index, y="quantity", title='Daily sales', template="simple_white")
# fig.update_traces(line=dict(width=1.5))
fig.add_trace(go.Scatter(x=forecast.index, y=forecast.values, mode='lines', name='Forecast Quantity'))
fig.update_layout(title_x=0.5, margin={'l': 30, 'b': 40, 't': 30, 'r': 40}, hovermode='x unified', hoverlabel=dict(bgcolor="white"))
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="Quantity")
fig.show()

# %%
rmse = mean_squared_error(df_orders_test['quantity'], forecast, squared=False)
rmse
# Out:
# 700.7036181691961
