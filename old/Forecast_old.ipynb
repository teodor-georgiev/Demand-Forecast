# %%
import warnings
disable_warnings = warnings.filterwarnings('ignore')
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# from statsforecast import StatsForecast
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error

# %%
orders_train = pd.read_csv('orders_train.txt', sep=';', encoding='utf8')
orders_class = pd.read_csv('orders_class.txt', sep=';', encoding='utf8')

# %%
df_whole = pd.concat([orders_train, orders_class], ignore_index=True)
df_whole
# Out:
#           orderID   orderDate articleID  colorCode sizeCode  productGroup  \
# 0        a1000001  2014-01-01  i1000382       1972       44           3.0
# 1        a1000001  2014-01-01  i1000550       3854       44           3.0
# 2        a1000002  2014-01-01  i1001991       2974       38           8.0
# 3        a1000002  2014-01-01  i1001999       1992       38           8.0
# 4        a1000003  2014-01-01  i1001942       1968       42           8.0
# ...           ...         ...       ...        ...      ...           ...
# 2666258  a1855500  2015-12-31  i1004262      20363       38        1231.0
# 2666259  a1855501  2015-12-31  i1000397       1000       44           3.0
# 2666260  a1855501  2015-12-31  i1001099       3085       42           3.0
# 2666261  a1855501  2015-12-31  i1004207      10107       42        1231.0
# 2666262  a1855502  2015-12-31  i1002423       1116       38          14.0
#
#          quantity  price    rrp voucherID  voucherAmount customerID  deviceID  \
# 0               1  10.00  29.99         0            0.0   c1010575         2
# 1               1  20.00  39.99         0            0.0   c1010575         2
# 2               1  35.00  49.99         0            0.0   c1045905         4
# 3               1  49.99  49.99         0            0.0   c1045905         4
# 4               1  10.00  35.99         0            0.0   c1089295         2
# ...           ...    ...    ...       ...            ...        ...       ...
# 2666258         1  29.99  29.99         0            0.0   c1225101         5
# 2666259         1  17.99  17.99         0            0.0   c1065053         5
# 2666260         1   9.00  29.99         0            0.0   c1065053         5
# 2666261         1  17.99  17.99         0            0.0   c1065053         5
# 2666262         1  45.00  89.99         0            0.0   c1082444         5
#
#         paymentMethod  returnQuantity
# 0                BPRG             0.0
# 1                BPRG             0.0
# 2                BPRG             0.0
# 3                BPRG             1.0
# 4            PAYPALVC             0.0
# ...               ...             ...
# 2666258          BPRG             NaN
# 2666259      PAYPALVC             NaN
# 2666260      PAYPALVC             NaN
# 2666261      PAYPALVC             NaN
# 2666262          BPRG             NaN
#
# [2666263 rows x 15 columns]

# %%
df_orders = df_whole[["orderDate","quantity"]].groupby("orderDate").sum()
df_orders
# Out:
#             quantity
# orderDate
# 2014-01-01      1245
# 2014-01-02      1586
# 2014-01-03      1709
# 2014-01-04      2495
# 2014-01-05      3485
# ...              ...
# 2015-12-27      2783
# 2015-12-28      4968
# 2015-12-29      4061
# 2015-12-30      3224
# 2015-12-31      1992
#
# [730 rows x 1 columns]

# %%
df_orders_train = df_orders.loc[:'2015-11-30']
df_orders_test = df_orders.loc['2015-12-01':]

# %%
fig = px.line(df_orders_train, x=df_orders_train.index, y="quantity", title='Daily sales', template="simple_white")
fig.add_trace(go.Scatter(x=df_orders_test.index, y=df_orders_test["quantity"], mode='lines', name='Test Quantity'))
fig.update_layout(title_x=0.5, margin={'l': 30, 'b': 40, 't': 30, 'r': 40}, hovermode='x unified', hoverlabel=dict(bgcolor="white"))
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="Quantity")
fig.show()

# %%
# Generate the ACF plot using statsmodels
acf_fig, ax = plt.subplots(figsize=(12, 8))  # Adjust the size as needed (width, height)
plot_acf(df_orders_train, lags=30, ax=ax)
plt.show()

# %%
# Perform the ADF test on the time series
result = adfuller(df_orders_train['quantity'])

# Extract the test statistic and p-value from the result
test_statistic = result[0]
p_value = result[1]

# Print the test statistic and p-value
print(f'Test statistic: {test_statistic:.4f}')
print(f'p-value: {p_value:.4f}')
# Out:
# Test statistic: -2.5305
# p-value: 0.1082

# %%
# Compute the first and second differences of the time series
diff1 = df_orders_train['quantity'].diff().dropna()
diff2 = diff1.diff().dropna()

# Perform the ADF test on the differences and print the results
for i, diff in enumerate([diff1, diff2], start=1):
    result = adfuller(diff)
    print(f'{i} difference: Test statistic = {result[0]:.4f}, p-value = {result[1]:.4f}')
# Out:
# 1 difference: Test statistic = -8.2093, p-value = 0.0000
# 2 difference: Test statistic = -11.9449, p-value = 0.0000

# %%
pacf_fig, ax = plt.subplots(figsize=(12, 8))  # Adjust the size as needed (width, height)
plot_pacf(diff1, lags=30, ax=ax)
plt.show()

# %%
acf_fig, ax = plt.subplots(figsize=(12, 8))  # Adjust the size as needed (width, height)
plot_acf(diff1, lags=30, ax=ax)
plt.show()

# %%
# Define the ARIMA model with p=6, d=1, and q=7
model = ARIMA(df_orders_train['quantity'], order=(6, 1, 7), freq='D')

# Fit the model to the data
model_fit = model.fit()

# Print the summary of the model
print(model_fit.summary())

# Make predictions for the next 31 time steps
forecast = model_fit.forecast(steps=31)

# Print the forecasted values
print(forecast)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               quantity   No. Observations:                  699
# Model:                 ARIMA(6, 1, 7)   Log Likelihood               -5476.956
# Date:                Tue, 25 Jul 2023   AIC                          10981.913
# Time:                        11:41:24   BIC                          11045.588
# Sample:                    01-01-2014   HQIC                         11006.530
#                          - 11-30-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9993      0.013    -79.882      0.000      -1.024      -0.975
# ar.L2         -0.9798      0.019    -50.995      0.000      -1.017      -0.942
# ar.L3         -0.9842      0.020    -49.850      0.000      -1.023      -0.945
# ar.L4         -0.9875      0.018    -54.551      0.000      -1.023      -0.952
# ar.L5         -0.9742      0.018    -55.086      0.000      -1.009      -0.940
# ar.L6         -0.9747      0.012    -78.836      0.000      -0.999      -0.950
# ma.L1          0.5889      0.041     14.316      0.000       0.508       0.670
# ma.L2          0.4769      0.047     10.196      0.000       0.385       0.569
# ma.L3          0.4089      0.046      8.847      0.000       0.318       0.500
# ma.L4          0.3944      0.047      8.367      0.000       0.302       0.487
# ma.L5          0.3969      0.049      8.072      0.000       0.301       0.493
# ma.L6          0.4153      0.046      9.067      0.000       0.325       0.505
# ma.L7         -0.4546      0.040    -11.433      0.000      -0.533      -0.377
# sigma2      4.193e+05   1.22e+04     34.486      0.000    3.95e+05    4.43e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.89   Jarque-Bera (JB):              6420.49
# Prob(Q):                              0.17   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                             1.60
# Prob(H) (two-sided):                  0.47   Kurtosis:                        17.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 2015-12-01    3229.766036
# 2015-12-02    3777.187125
# 2015-12-03    3862.070735
# 2015-12-04    3185.338768
# 2015-12-05    2840.251205
# 2015-12-06    3256.754413
# 2015-12-07    2743.704648
# 2015-12-08    3240.011446
# 2015-12-09    3754.107911
# 2015-12-10    3843.463743
# 2015-12-11    3199.271347
# 2015-12-12    2853.240667
# 2015-12-13    3251.133538
# 2015-12-14    2753.755130
# 2015-12-15    3249.552787
# 2015-12-16    3731.992981
# 2015-12-17    3825.641248
# 2015-12-18    3212.249227
# 2015-12-19    2865.763826
# 2015-12-20    3246.192619
# 2015-12-21    2763.494716
# 2015-12-22    3258.436253
# 2015-12-23    3710.796799
# 2015-12-24    3808.564453
# 2015-12-25    3224.328325
# 2015-12-26    2877.840140
# 2015-12-27    3241.881544
# 2015-12-28    2772.937038
# 2015-12-29    3266.705130
# 2015-12-30    3690.476202
# 2015-12-31    3792.196702
# Freq: D, Name: predicted_mean, dtype: float64

# %%
fig = px.line(df_orders["2015-10-01":], x=df_orders["2015-10-01":].index, y="quantity", title='Daily sales', template="simple_white")
# fig.update_traces(line=dict(width=1.5))
fig.add_trace(go.Scatter(x=forecast.index, y=forecast.values, mode='lines', name='Forecast Quantity'))
fig.update_layout(title_x=0.5, margin={'l': 30, 'b': 40, 't': 30, 'r': 40}, hovermode='x unified', hoverlabel=dict(bgcolor="white"))
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="Quantity")
fig.show()

# %%
rmse = mean_squared_error(df_orders_test['quantity'], forecast, squared=False)
rmse
# Out:
# 1091.4259880516322

# %%
df_orders_train["holiday"] = 0
df_orders_train.loc[["2014-12-24", "2014-12-31"], "holiday"] = 1
df_orders_test["holiday"] = 0
df_orders_test.loc[["2015-12-24", "2015-12-31"], "holiday"] = 1

# %%
# # Convert the index to a datetime index
# df_orders_train.index = pd.to_datetime(df_orders_train.index)
# df_orders_test.index = pd.to_datetime(df_orders_test.index)

# # Create dummy variables for 'day_of_week' in both DataFrames
# df_dummies_train = pd.get_dummies(df_orders_train.index.dayofweek, prefix='day_of_week')
# df_dummies_train.index = df_orders_train.index
# df_dummies_test = pd.get_dummies(df_orders_test.index.dayofweek, prefix='day_of_week')
# df_dummies_test.index = df_orders_test.index


# # Rename the columns of the dummy variable DataFrame to correspond to the name of the days
# df_dummies_train.columns = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# df_dummies_test.columns = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# # Concatenate the original DataFrame and the dummy variable DataFrame
# df_orders_train = pd.concat([df_orders_train, df_dummies_train], axis=1)
# df_orders_test = pd.concat([df_orders_test, df_dummies_test], axis=1)

# %%
# Define the SARIMA model with p=6, d=1, q=7, P=1, D=1, and Q=1
model = SARIMAX(endog = df_orders_train['quantity'], exog=df_orders_train.iloc[:, 1:] ,order=(6, 1, 4), seasonal_order=(4, 1, 4, 7), freq='D')

# Fit the model to the data
model_fit = model.fit()

# Print the summary of the model
print(model_fit.summary())

# Make predictions for the next 31 time steps
exog_forecast = df_orders_test.iloc[:, 1:]
forecast = model_fit.forecast(steps=31, exog=exog_forecast)

# Print the forecasted values
print(forecast)
# Out:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                          quantity   No. Observations:                  699
# Model:             SARIMAX(6, 1, 4)x(4, 1, 4, 7)   Log Likelihood               -5450.013
# Date:                           Tue, 25 Jul 2023   AIC                          10954.026
# Time:                                   14:15:27   BIC                          11076.556
# Sample:                               01-01-2014   HQIC                         11001.419
#                                     - 11-30-2015
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# holiday     -398.5212    360.023     -1.107      0.268   -1104.154     307.111
# Monday        -0.0009   4385.782  -2.09e-07      1.000   -8595.977    8595.975
# Tuesday        0.0066   2734.945   2.42e-06      1.000   -5360.387    5360.401
# Wednesday   4.021e-05   5276.028   7.62e-09      1.000   -1.03e+04    1.03e+04
# Thursday       0.0006   4148.052   1.53e-07      1.000   -8130.032    8130.034
# Friday         0.0005   3901.498   1.22e-07      1.000   -7646.795    7646.796
# Saturday      -0.0011   3616.572  -3.13e-07      1.000   -7088.353    7088.350
# Sunday        -0.0013   3046.147  -4.39e-07      1.000   -5970.339    5970.336
# ar.L1         -0.2310      0.610     -0.379      0.705      -1.427       0.965
# ar.L2          0.3975      0.558      0.713      0.476      -0.696       1.491
# ar.L3          0.6219      0.176      3.528      0.000       0.276       0.967
# ar.L4         -0.3089      0.382     -0.808      0.419      -1.058       0.440
# ar.L5          0.0366      0.105      0.349      0.727      -0.169       0.242
# ar.L6          0.0810      0.087      0.934      0.350      -0.089       0.251
# ma.L1         -0.1537      0.616     -0.249      0.803      -1.362       1.054
# ma.L2         -0.6930      0.335     -2.069      0.039      -1.349      -0.037
# ma.L3         -0.6586      0.268     -2.459      0.014      -1.184      -0.134
# ma.L4          0.5463      0.602      0.907      0.364      -0.634       1.726
# ar.S.L7       -0.6360     14.518     -0.044      0.965     -29.091      27.819
# ar.S.L14       0.4088      1.387      0.295      0.768      -2.309       3.127
# ar.S.L21       0.3345      5.398      0.062      0.951     -10.245      10.914
# ar.S.L28       0.0735      1.420      0.052      0.959      -2.710       2.857
# ma.S.L7       -0.2760     14.512     -0.019      0.985     -28.720      28.168
# ma.S.L14      -1.0109     14.392     -0.070      0.944     -29.219      27.197
# ma.S.L21       0.1260      4.678      0.027      0.979      -9.042       9.294
# ma.S.L28       0.2159      4.981      0.043      0.965      -9.546       9.978
# sigma2      6.551e+05   4.16e+04     15.763      0.000    5.74e+05    7.37e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):              5891.97
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.94   Skew:                             1.62
# Prob(H) (two-sided):                  0.61   Kurtosis:                        16.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 2015-12-01    3813.084809
# 2015-12-02    4150.853131
# 2015-12-03    4050.756790
# 2015-12-04    3351.409784
# 2015-12-05    2910.130121
# 2015-12-06    3503.749956
# 2015-12-07    2764.085773
# 2015-12-08    3738.159595
# 2015-12-09    4127.271939
# 2015-12-10    3959.400059
# 2015-12-11    3342.633036
# 2015-12-12    2981.289028
# 2015-12-13    3344.958689
# 2015-12-14    2802.026517
# 2015-12-15    3742.308446
# 2015-12-16    4166.059275
# 2015-12-17    4063.783833
# 2015-12-18    3338.954426
# 2015-12-19    2914.797901
# 2015-12-20    3421.220877
# 2015-12-21    2752.797823
# 2015-12-22    3790.501900
# 2015-12-23    4147.041176
# 2015-12-24    3590.583966
# 2015-12-25    3349.251088
# 2015-12-26    2916.821041
# 2015-12-27    3374.084222
# 2015-12-28    2785.017671
# 2015-12-29    3736.007067
# 2015-12-30    4175.584532
# 2015-12-31    3595.017343
# Freq: D, Name: predicted_mean, dtype: float64

# %%
fig = px.line(df_orders["2015-10-01":], x=df_orders["2015-10-01":].index, y="quantity", title='Daily sales', template="simple_white")
# fig.update_traces(line=dict(width=1.5))
fig.add_trace(go.Scatter(x=forecast.index, y=forecast.values, mode='lines', name='Forecast Quantity'))
fig.update_layout(title_x=0.5, margin={'l': 30, 'b': 40, 't': 30, 'r': 40}, hovermode='x unified', hoverlabel=dict(bgcolor="white"))
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="Quantity")
fig.show()

# %%
rmse = mean_squared_error(df_orders_test['quantity'], forecast, squared=False)
rmse
# Out:
# 1068.362647723083
